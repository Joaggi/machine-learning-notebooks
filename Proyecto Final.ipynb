# %% [markdown]
# https://tomaugspurger.github.io/modern-6-visualization.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 0. Cargue las librerias que usara en el proyecto
#
# Recuerde usar librerias para graficar, numpy y pandas, entre otras.

# %% [markdown]
# # 1. Cargue sus datos
#
# Por favor cargue los datos en la siguiente sección

# %% [markdown]
# # 1.1 Realice limpieza de datos. En este paso se deben revisar variables nulas y detectar posibles errores (se deben utilizar gráficas y matrices para este paso)

# %% [markdown]
# # 1.2. ¿Qué pregunta(s) quiere responder a partir de sus datos?

# %% [markdown]
# # 1.3. Describa a continuacíon los datos de forma precisa.

# %% [markdown]
# Construir el diccionario de datos, y un resumen de los datos.

# %% [markdown]
# ## 1.4 Objetivos

# %% [markdown]
# - Objetivo general
# - Objetivos especificos

# %% [markdown]
# ## 1.5 Hipótesis

# %% [markdown]
# # 2. Muestre los datos de forma descriptiva
#
# Use funciones de pandas para mostrar las características de los datos

# %% [markdown]
# - Utilice media, varianza,
# - Info()
# - Describe()
# - Head
# - Tail
# - Sample
# - Max
# - Min
# - Kurtosis
# - Sesgo

# %% [markdown]
# # 3 Transforme las variables categóricas y continuas en variables que entienda el modelo de predicción.
#
# Recuerde tener en cuenta si las variables son categóricas (nominales, ordinales) o numéricas (discretas, continuas).
#
# https://medium.com/hugo-ferreiras-blog/dealing-with-categorical-features-in-machine-learning-1bb70f07262d
#
# - TargetEncoding
# - LabelEncoding
# - OneHotEncoding
# - CategoricalEncoding

# %% [markdown]
# # 3.1 Realice un preprocesamiento de los datos.
# Con esto se pretende ver si llevando los datos a un espacio de menor dimensionalidad impacta al modelo. Se debe entrenar el modelo con los datos crudos y con los datos preprocesados.

# %% [markdown]
# - Estandarizar (Min Max Scaler)
# - Normalizar (StandarScaler)

# %% [markdown]
# - Reducir dimensionalidad (PCA, t-sne, umap,  random-projections, feature agglomeration u otras) ¿Qué pasa si aplico reducción de dimensionalidad y qué pasa si no lo aplico? ¿Qué pasa si vario el número de componentes que uso para mi modelo?

# %% [markdown]
# - Quitar datos atípicos (estrategias, media, variaza, clipping, detección de datos atipicos)
#
# Una libreria recomendada es Missingno
#
# https://towardsdatascience.com/using-the-missingno-python-library-to-identify-and-visualise-missing-data-prior-to-machine-learning-34c8c5b5f009

# %% [markdown]
# - Transformaciones personalizadas (mean encoding, categorical encoding, label encoding)
#
# https://towardsdatascience.com/custom-transformers-in-python-part-ii-6fe111fc82e4

# %% [markdown]
# # 4. Grafique los datos con pairplot
#
# Cargue alguna libreria para hacer las graficas más amigables
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.1 ¿Qué puede extraer de los datos con esta gráfica?

# %% [markdown]
# Muestra todas las combinaciones de la información existente de tipo numérico o float

# %% [markdown]
# # 5. Particione los datos en entrenamiento y prueba
#
# Verifique que tipo de partición debe realizar, ya que sus datos pueden ser de tipo series de tiempo
#
# `train_test_split`
#
# Rucuerden que en el caso de serie de tiempo es recomendable utilizar `shuffle=false` y que los datos esten cronologicamente ordenados del más antiguo al más nuevo.
#
# También recuerde que en el caso de datos desbalanceados es recomendable utilizar estratificación.
#
# Si sus datos estan con un desbalance de más del 80% a una de las clases se debe utilizar tecnicas de submuestreo y sobremuestreo.
#
# https://imbalanced-learn.org/dev/references/generated/imblearn.over_sampling.SMOTE.html

# %% [markdown]
# # 6. Partione en subconjunto de entrenamiento y validación

# %% [markdown]
# Particione sus datos en entrenamiento y validación para la busqueda de hiperparámetros (recuerde por favor no buscar hiperparametros usando la partición de prueba). Recuerde que puede utilizar otras estrategias como k-fold o one-hold-out. Para el caso de series de tiempo recuerde usar `time_series_split` de sklearn para la busqueda de hiperparametros.

# %% [markdown]
# # 7. Realice el escalamiento o normalización que requieran los datos
#
# Rucuerden que el escalamiento se realiza el fit en entrenamiento y el transform tanto en entrenamiento como pueba. Recuerde en este punto utilizar los Pipelines de ejecución para que las transformaciones se apliquen de manera secuencial.

# %% [markdown]
# # 8. Métodos no supervisados de agrupacion

# %% [markdown]
# La idea en este punto es probar varios métodos no supervisados.
#
# Posibles métodos:
#
# - K-means
# - Kmedoids
# - Spectral Clustering
# - DbScan
# - Tsne
# - Affinity Propagation
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.cluster
#
# https://scikit-learn.org/stable/modules/clustering.html#clustering

# %% [markdown]
# ## Métricas:
#
# - Intrinsecas (inercia, coeficiente silueta)
# - Extrinsecas (Matriz Contingencia, homogeneidad, completez, v-score, f1-score, indice rand, )

# %% [markdown]
# # 8. Métodos supervisados

# %% [markdown]
# Posibles métodos:
#
# - SVM
# - Random Forest
# - Decision Trees
# - Gradient Boosting Descent
# - Naive Bayes
# - Knn
# - Redes neuronales
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.neural_network
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.naive_bayes
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.kernel_approximation

# %% [markdown]
# Métricas:
#
# - Clasificación
#
#   - Accuracy
#   - Precision (Macro, Micro, Average)
#   - Recall (Macro, Micro, Average)
#   - F1-Score (Macro, Micro, Average)
#   - Sensitivity
#   - Auc-PR
#   - Auc-ROC
#   - Matriz de confusión
#
# - Regresión:
#
#   - MSE (mean squared error)
#   - RMSE (root mean squared erro)
#   - Log MSE
#   - MAE( mean average error)
#   - R^2

# %% [markdown]
# Metodología para encontrar hiperparametros con grid search cv o random search cv
#
# ![image.png](data:image/png;base64,...)
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection

# %% [markdown]
# Enlaces para series de tiempo:
# https://www.kaggle.com/code/vlasoff/catboost-forget-about-time-series/notebook
# Tú10:11
# https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/
# Tú10:14
# https://hackernoon.com/advanced-techniques-for-time-series-data-feature-engineering

# %% [markdown]
# ## ¿Cuál fue el mejor algoritmo que funcionó para sus datos?

# %% [markdown]
# ## ¿Por qué cree que fue el que mejor funcionó?

# %% [markdown]
# ## ¿Qué otras técnicas cree que puede utilizar para mejorar su algoritmo?

# %% [markdown]
# ## ¿Los métodos aplicados le ayudaron a responder sus preguntas con base en los datos? Trate de mostrar gráficamente la información extraida del proceso.

# %% [markdown]
# ## ¿Le hicieron falta datos?, realice una conjetura sobre como podría obtener mejores resultados.

# %% [markdown]
# # Conclusiones
